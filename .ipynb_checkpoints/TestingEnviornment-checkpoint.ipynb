# %%
import pandas as pd

# %%
# %run test.py
# Out:
# .......
# ----------------------------------------------------------------------
# Ran 7 tests in 0.053s
#
# OK

# %%
d = {'Predictor I': [2, 4, 6, 6], 'Predictor II': [5, 5, 6, 5], 'Predictor III': [10, 5, 8, 8]}
df = pd.DataFrame(data=d)


d1 = {'Real Value': [6, 5, 6, 7]}
df1 = pd.DataFrame(data=d1)

# %%
# %run algorithms.py

# %%
# %run dataloader.py

# %%
test = Dataloader('aapl', '2010-01-30', '2021-01-01')

# %%
print(test)
# Out:
# Total count of rows: 2750
# Ticker: aapl
# Start: 2010-01-30
# End: 2021-01-01

# %%
test.plotting()

# %%
test.statistics()
# Out:
#               High          Low         Open        Close        Volume  \
# count  2750.000000  2750.000000  2750.000000  2750.000000  2.750000e+03
# mean     34.297807    33.593741    33.945984    33.959654  2.830804e+08
# std      24.882535    24.206754    24.548584    24.559267  2.230785e+08
# min       7.000000     6.816071     6.870357     6.858929  4.544800e+07
# 25%      17.938572    17.597322    17.788392    17.796072  1.207462e+08
# 50%      27.331250    26.832500    27.143750    27.117500  2.015364e+08
# 75%      43.483750    42.740626    43.098124    43.071249  3.848418e+08
# max     138.789993   134.339996   138.050003   136.690002  1.880998e+09
#
#          Adj Close
# count  2750.000000
# mean     32.194820
# std      24.964407
# min       5.898012
# 25%      15.564989
# 50%      25.059515
# 75%      41.608532
# max     136.254608

# %%
u = test.calculate_returns_adj()

# %%
u
# Out:
#               Return
# Date
# 2010-02-01       NaN
# 2010-02-02  0.034704
# 2010-02-03  0.103496
# 2010-02-04 -0.220505
# 2010-02-05  0.104726
# ...              ...
# 2020-12-24  1.006775
# 2020-12-28  4.704971
# 2020-12-29 -1.814209
# 2020-12-30 -1.146332
# 2020-12-31 -1.026718
#
# [2750 rows x 1 columns]
